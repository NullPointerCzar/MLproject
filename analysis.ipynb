# %%
import numpy as np
import re
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <b><h3># Open the chat log file "_chat.txt" for reading with UTF-8 encoding
# <h3></b>

# %%
f = open("_chat 2.txt", "r", encoding="utf-8")

# %% [markdown]
# <strong><h3>Read the chat log file named "_chat.txt" with UTF-8 encoding and store its content in the variable 'data'.</strong><h3>

# %%
data = f.read()

# %%
print(data)
# Out:
# [15/11/2024, 11:54:43] NCE 2080 BCT: ‎Messages and calls are end-to-end encrypted. Only people in this chat can read, listen to, or share them.
# [15/11/2024, 11:54:43] ~ Er.SP: ‎~ Er.SP created this group
# [15/11/2024, 11:54:43] NCE 2080 BCT: ‎You were added
# [25/03/2025, 21:18:32] ~ Er.SP: ‎Waiting for this message. This may take a while.
# [25/03/2025, 21:18:33] ~ Er.SP: ‎Waiting for this message. This may take a while.
# [25/03/2025, 21:18:33] ~ Er.SP: ‎Waiting for this message. This may take a while.
# [25/03/2025, 21:32:29] ~ Er.SP: ‎Waiting for this message. This may take a while.
# [25/03/2025, 21:32:32] ~ Er.SP: ‎Waiting for this message. This may take a while.
# [26/03/2025, 08:15:21] Suroj Burlakoti: ‎Waiting for this message. This may take a while.
# [29/03/2025, 10:02:26] ~ Er.SP: ‎Waiting for this message. This may take a while.
# [05/04/2025, 20:07:05] ‪+977 984‑9213538‬: ‎‪+977 984‑9213538‬ left
# [15/04/2025, 22:55:20] ‪+9779766479265‬: ‎‎‪+9779766479265‬ changed their phone number to a new number. ‎Tap to message new number.
# ‎[21/04/2025, 11:13:12] Suroj Burlakoti: ‎image omitted
# ‎[06/05/2025, 08:54:56] Suroj Burlakoti: ‎image omitted
# [06/05/2025, 08:58:46] Suroj Burlakoti: Dear Student, The Instrumentation class for tomorrow is shifted to 12:30 PM. So please reach college at 8:40AM for tomorrow.
# [06/05/2025, 21:57:38] ~ Sahil Subedi: ‎~ Er.SP added ~ Sahil Subedi
# [12/05/2025, 13:14:41] Ranjit KC: ‎Suroj Burlakoti added Ranjit KC
# [07/05/2025, 14:06:26] Suroj Burlakoti: Dear students,
# The class of Instrumentation for tomorrow morning is shifted to 11:00 AM. Please reach college at 8:40 AM. Those students who will absent without valid reason will be marked and listed for counseling with parents for next week.
# [07/05/2025, 17:29:45] Suroj Burlakoti: Class routine for tomorrow
# 8:45-10:15 Data Communication
# 11:00- 12:30 Instrumentation
# 12:30-2:00 Operating System
# ‎[08/05/2025, 10:53:03] Suroj Burlakoti: Electromagnetics Syllabus new.pdf • ‎3 pages ‎document omitted
# ‎[08/05/2025, 12:15:00] Suroj Burlakoti: DSA syllabus new.pdf • ‎4 pages ‎document omitted
# ‎[08/05/2025, 12:17:01] Suroj Burlakoti: Data communication syllabus new.pdf • ‎3 pages ‎document omitted
# ‎[08/05/2025, 12:18:44] Suroj Burlakoti: Operating System syllabus new.pdf • ‎3 pages ‎document omitted
# ‎[08/05/2025, 12:21:16] Suroj Burlakoti: Instrumentation Syllabus new.pdf • ‎4 pages ‎document omitted
# [08/05/2025, 16:25:58] Asim Poudel: Sir bholi Pani instrumentation deuso hune ho?
# [08/05/2025, 17:09:30] Suroj Burlakoti: Dear students, there will be Operating system class on tomorrow morning starting from 7:05 AM. Please reach college at 7:00 AM sharp.
# [08/05/2025, 17:10:14] Suroj Burlakoti: OS and Instrumentation swapped.
# [08/05/2025, 17:10:27] Asim Poudel: Alright
# [11/05/2025, 17:34:16] Suroj Burlakoti: Dear Student, please reach college at 7:00 AM sharp for Monday
# Class routine for tomorrow :
# 7:05-8:45 Electromagnetics
# 8:45-10:15 Data Communication
# 11:00-12:30 Instrumentation
# 12:30-2:00 Operating System
# ‎[12/05/2025, 12:42:18] ~ Er.SP: ‎image omitted
# ‎[12/05/2025, 15:01:50] Ranjit KC: chap 1 notes by Ranjit K.C..pdf • ‎28 pages ‎document omitted
# ‎[12/05/2025, 20:50:46] ~ Sahil Subedi: EM Tutorial 1.pdf • ‎1 page ‎document omitted
# ‎[17/05/2025, 15:42:44] Suroj Burlakoti: ‎image omitted
# [17/05/2025, 15:50:05] Asim Poudel: Sir vayena esto ta
# [17/05/2025, 15:50:15] Asim Poudel: Friday ko 4 15 sammai hune?
# [21/05/2025, 20:41:47] Suroj Burlakoti: Dear students, there will be no class of Instrumentation for tomorrow morning due to faculty unavailability. Please reach college at 8:45 AM. Sorry for your inconvenience.
# [23/05/2025, 13:22:54] Sarwagya Acharya: ‎You deleted this message.
# ‎[23/05/2025, 14:34:24] Suroj Burlakoti: ‎image omitted
# ‎[27/05/2025, 22:31:07] ~ Sahil Subedi: EM Tutorial 2.pdf • ‎2 pages ‎document omitted
# [30/05/2025, 10:16:32] ~ Sahil Subedi: Syllabus of EM for third weekly test: Derivation of electric field intensity using Gauss's law. (Due to all types of charges)
# [02/06/2025, 06:24:56] ~ Er.SP: Due to an unavoidable  situation, there will be no regular classes today (Monday, 2 June, 2025).
# [02/06/2025, 09:02:03] ~ Sahil Subedi: Dear Students,
#
# This is to inform you that a unit test of Electromagnetics will be held on Friday, 2082/02/23, covering Chapters 1 and 2.
# The test will begin at 8:45 AM.
#
# For the test content, please refer to the provided PDF file “Practice Questions”. The questions in the test will be based on that file.
# ‎[02/06/2025, 09:02:25] ~ Sahil Subedi: Practice Questions EM.pdf • ‎2 pages ‎document omitted
# ‎[03/06/2025, 15:32:39] ~ Er.SP: ‎image omitted
# [03/06/2025, 21:48:22] Suroj Burlakoti: Dear Students, there will be regular classes from tomorrow. Please reach college at 7:00AM.
# ‎[13/06/2025, 12:51:57] Suroj Burlakoti: ‎image omitted
# [13/06/2025, 16:39:36] Asim Poudel: Sir 3 gate wala lai last ma shift garda hunxa ?
# Welcome 1 ma ... 2 ma sabai exhausted hunxam..so alik garo parxa hola
# ‎[16/06/2025, 09:11:34] ~ Sahil Subedi: Practice Ques for Assess 1 (EM).pdf • ‎2 pages ‎document omitted
# [16/06/2025, 09:11:58] ~ Sahil Subedi: EM Practice Questions for Assessment 1
# [16/06/2025, 10:01:06] Suroj Burlakoti: Dear students, the Assessment exam of DSA is shifted to Wednesday (2082/03/04) at 12:30 PM as per CR request.
# There will be no class of DSA for tomorrow morning due to faculty unavailability. ‎<This message was edited>
# ‎[17/06/2025, 12:54:45] Suroj Burlakoti: ‎image omitted
# [17/06/2025, 12:54:52] Suroj Burlakoti: revised
# [18/06/2025, 09:15:34] ~ Sahil Subedi: Dear Students,
# Please collect your tutorial copy of EM.
# ‎[23/06/2025, 18:21:47] ~ Sahil Subedi: ‎image omitted
# [23/06/2025, 18:21:55] ~ Sahil Subedi: ‎This message was deleted.
# [23/06/2025, 18:22:22] ~ Sahil Subedi: Solution of Q3 and Q14 from Practice Set
# [23/06/2025, 18:23:55] ~ Sahil Subedi: ‎This message was deleted.
# ‎[23/06/2025, 18:24:43] ~ Sahil Subedi: ‎image omitted
# [26/06/2025, 09:03:59] ~ Sahil Subedi: Dear Students,
# Please collect your tutorial copy of EM.
# [30/06/2025, 15:51:43] Ranjit KC: %Amplitude modulation
# clc;
# clear;
#
# % Time and sampling setup
# fs = 10000;                  % Sampling frequency
# t = 0:1/fs:0.1;              % Time vector (100 ms)
# N = length(t);               % Number of samples
# f = linspace(-fs/2, fs/2, N); % Frequency vector for FFT
#
# % Message signals
# Am1 = 1;
# fm1 = 50;                    % Message signal 1 frequency
# msg1 = Am1 * cos(2*pi*fm1*t);
#
# Am2 = 1;
# fm2 = 120;                   % Message signal 2 frequency
# msg2 = Am2 * cos(2*pi*fm2*t);
#
# msg_total = msg1 + msg2;
#
# % Carrier signal (LOWER frequency for visible envelope)
# Ac = 1;                      % Carrier amplitude
# fc = 1000;                    % Carrier frequency
# carrier = Ac * cos(2*pi*fc*t);
#
# % Modulation index < 1
# mu = 1; %test all 3 cases
#
# % AM Modulated Signals
# AM_single = Ac * (1 + mu * msg1) .* cos(2*pi*fc*t);
# AM_dual   = Ac * (1 + mu * msg_total) .* cos(2*pi*fc*t);
#
# % FFT of AM signals
# FFT_single = fftshift(abs(fft(AM_single))/N);
# FFT_dual   = fftshift(abs(fft(AM_dual))/N);
#
# % Plotting
# figure;
# subplot(3,3,1);
# plot(t, msg1);
# title('Message Signal 1');
# xlabel('Time (s)');
# ylabel('Amplitude');
# grid on;
#
# subplot(3,3,2);
# plot(t, msg2);
# title('Message Signal 2');
# xlabel('Time (s)');
# ylabel('Amplitude');
# grid on;
#
# subplot(3,3,3);
# plot(t, carrier);
# title('Carrier Signal');
# xlabel('Time (s)');
# ylabel('Amplitude');
# grid on;
#
# subplot(3,3,4);
# plot(t, AM_single);
# title('Single-Tone AM');
# xlabel('Time (s)');
# ylabel('Amplitude');
# grid on;
#
# subplot(3,3,5);
# plot(f, FFT_single);
# title('FFT: Single-Tone AM');
# xlabel('Frequency (Hz)');
# ylabel('Magnitude');
# xlim([-1120 1120]);  % Focus around ±fc ± fm
# grid on;
#
# subplot(3,3,6);
# plot(t, msg_total);
# title('Combined Message Signal');
# xlabel('Time (s)');
# ylabel('Amplitude');
# grid on;
#
# subplot(3,3,7);
# plot(t, AM_dual);
# title('Dual-Tone AM');
# xlabel('Time (s)');
# ylabel('Amplitude');
# grid on;
#
# subplot(3,3,8);
# plot(f, FFT_dual);
# title('FFT: Dual-Tone AM');
# xlabel('Frequency (Hz)');
# ylabel('Magnitude');
# xlim([-1120 1120]);  % Focus around ±fc ± fm1 ± fm2
# grid on;
# [30/06/2025, 15:51:44] Ranjit KC: %Frequency modulation
#
# clc;
# clear;
#
# % Time and frequency setup
# fs = 10000;                 % Sampling frequency
# t = 0:1/fs:0.1;             % Time vector (100 ms)
# N = length(t);              % Number of samples
# f = linspace(-fs/2, fs/2, N); % Frequency axis for FFT
#
# % Message signal (single tone)
# Am = 1;
# fm = 50;
# msg = Am * cos(2*pi*fm*t);  % Message signal
#
# % Carrier signal
# Ac = 1;
# fc = 200;
# carrier = Ac * cos(2*pi*fc*t);
#
# % Modulation index beta = 1
# beta = 1;
# kf = beta * fm / Am;        % Frequency deviation constant
#
# % Frequency Modulated signal
# int_msg = cumsum(msg)/fs;   % Numerical integration (∫m(t) dt)
# FM = Ac * cos(2*pi*fc*t + 2*pi*kf*int_msg);  % FM signal
#
# % FFT of FM signal
# FM_fft = fftshift(abs(fft(FM))/N);
#
# % Plotting
# figure;
#
# subplot(2,2,1);
# plot(t, msg);
# title('Message Signal (Single Tone)');
# xlabel('Time (s)');
# ylabel('Amplitude');
# grid on;
#
# subplot(2,2,2);
# plot(t, carrier);
# title('Carrier Signal');
# xlabel('Time (s)');
# ylabel('Amplitude');
# grid on;
#
# subplot(2,2,3);
# plot(t, FM);
# title(['Frequency Modulated Signal, \beta = ' num2str(beta)]);
# xlabel('Time (s)');
# ylabel('Amplitude');
# grid on;
#
# subplot(2,2,4);
# plot(f, FM_fft);
# title('FFT of FM Signal');
# xlabel('Frequency (Hz)');
# ylabel('Magnitude');
# xlim([-600 600]);  % Focused range
# grid on;
# ‎[04/07/2025, 20:58:17] ~ Sahil Subedi: EM Tutorial 3.pdf ‎document omitted
# [04/07/2025, 21:08:10] ~ Sahil Subedi: ‎~ Sahil Subedi changed this group's icon
# ‎[08/07/2025, 12:36:14] ~ Sahil Subedi: Capacitance (Remaining...).pdf • ‎11 pages ‎document omitted
# [19/07/2025, 16:10:47] Suroj Burlakoti: Dear students, there will be electromagnetics class for Monday morning starting from 7:05AM in place of weekly test.
# [22/07/2025, 18:31:27] ~ Sahil Subedi: ‎This message was deleted.
# [22/07/2025, 18:32:40] ~ Sahil Subedi: *Reminder for Tomorrow:* Please ensure you are well-prepared with the following formulas and concepts.
# 1. Attenuation Constant (α), Phase Constant (β), and Intrinsic Impedance (η) for all types of media.
# 2. Wave Equations for different media
# 3. Loss Tangent for various media.
# 4. Skin Depth formula
# 5. Reflection Coefficient (Γ), Transmission Coefficient (T), and Input Intrinsic Impedance
# [27/07/2025, 19:20:40] Suroj Burlakoti: MONDAY 7:05 DSA class
# ‎[29/07/2025, 07:16:16] Suroj Burlakoti: ‎image omitted
# [30/07/2025, 17:48:59] Suroj Burlakoti: class schedule for tomorrow
# 7:15 - 10:15 DSA
# 11 Onwards - DSA lab exam
# [30/07/2025, 20:34:23] ~ Sahil Subedi: This is to inform all students that a test of Electromagnetics will be conducted on Friday, 2082/04/16.
# Chapter Covered: Transmission Line
# Format: 2 questions (5 marks each)
# Duration: 30 minutes
# Test Timing: Will be informed later
# ***Please note that the marks obtained in this test will be added to your lab evaluation.
# Breakdown of Practical Marks (Total: 25):
# Attendance: 6 marks
# Report: 9 marks
# Exam: 10 marks (includes this test)
# [31/07/2025, 19:21:45] Suroj Burlakoti: class schedule for tomorrow
# 7:15 - 10:00 AM- DSA
# 11:00-11:30 AM-  Electromagnetics Exam
# ‎[05/08/2025, 11:09:22] Suroj Burlakoti: 2080 BCT 4th Sem.pdf • ‎2 pages ‎document omitted
# [05/08/2025, 17:29:57] ~ Sahil Subedi: ‎This message was deleted.
# ‎[05/08/2025, 17:34:19] ~ Sahil Subedi: EM lab evaluation.pdf • ‎1 page ‎document omitted
# [13/08/2025, 20:42:11] ~ Sahil Subedi: *Notice:* Students who did not pass the final assessment are required to appear for a re-exam.
# Re-exam date: *2082/05/04* (Wednesday)
# Time: *11:00 AM*
# *Syllabus for re-exam*
# 1. Magnetic Field
# 2. Time Varying Field
# 3. Plane Waves
# ‎[19/08/2025, 08:21:04] ~ Sahil Subedi: ‎image omitted
# [19/08/2025, 17:26:25] ~ Sahil Subedi: Dear Students, the re-exam scheduled on 2082/05/04 (Wednesday) has been *rescheduled* to *8:30 AM* instead of 11:00 AM.
# [20/08/2025, 08:18:02] ~ Sahil Subedi: Re- Exam: Room no. 101
# ‎[20/08/2025, 10:13:50] ~ Sahil Subedi: ‎image omitted
# ‎[20/08/2025, 10:13:56] ~ Sahil Subedi: ‎image omitted
# ‎[21/08/2025, 13:42:22] ~ Sahil Subedi: ‎image omitted
# [21/08/2025, 13:42:50] ~ Sahil Subedi: Yo copy kasko ho, liyera jane
# ‎[21/08/2025, 21:24:00] ~ Er.SP: ‎image omitted
# [22/08/2025, 10:01:03] ~ Sahil Subedi: You can collect assessment copy of EM from my cabin.
# [22/08/2025, 10:03:29] ~ Sahil Subedi: Don't miss dot product and vector sign in your answer. You may get zero marks in final exam. Practice past questions, tutorial, and assessment question of other colg.
# ‎[22/08/2025, 11:18:33] Suroj Burlakoti: OS Internal Marks -080 BCT.pdf • ‎2 pages ‎document omitted
# ‎[22/08/2025, 12:23:59] Suroj Burlakoti: EM internal marks.pdf • ‎2 pages ‎document omitted
# ‎[22/08/2025, 12:48:35] Suroj Burlakoti: Instrumentation.pdf • ‎2 pages ‎document omitted
# ‎[22/08/2025, 12:50:16] Suroj Burlakoti: DSA internal.pdf • ‎2 pages ‎document omitted
# ‎[22/08/2025, 12:51:06] Suroj Burlakoti: Data communication internal.pdf • ‎2 pages ‎document omitted
# [09/09/2025, 09:18:19] Suroj Burlakoti: *Dear Students,*
# In light of the tragic national situation and the ongoing curfew, today’s scheduled exam has been postponed.
# 👉 Please note that the rest of the exam schedule remains unchanged as of now, further notice will be shared if there are any additional changes.
# - Strictly remain indoors and avoid unnecessary movement during curfew.
# - Limit news and social media consumption to avoid stress and distraction.
# - Revise calmly and prepare for your next exams
# - Stay connected with family, friends and teachers.
# - Follow official communication and reliable news sources for updates.
#
# - Your safety and academic progress are both important. Let us stay strong, cautious, and focused together during this difficult time.
#
# HoD
# Department of Electronics & Computer Engineering
# National College of Engineering
# ‎[09/09/2025, 10:32:19] ~ Er.SP: ‎image omitted
# ‎[10/09/2025, 16:47:17] ~ Er.SP: ‎image omitted
# [11/09/2025, 11:32:08] Suroj Burlakoti: Dear Students,
#
# Please be informed that IOE will not conduct any postponed regular exams before Tihar (as per conversation between principal sir and Dean sir).
# 👉 The IOE Exam Control Division will publish an official notice at least *one week* before resuming exams.
#
# Stay safe and continue your preparation calmly.
#
# — Department of Electronics & Computer Engineering, NCE
# ‎[11/09/2025, 11:35:18] Suroj Burlakoti: ‎image omitted

# %% [markdown]
# <strong><h3>#Feed the logs instances to AI and let it generate a regex pattern for you
# <h3></strong>

# %%
pattern = r'^\[(\d{1,2}\/\d{1,2}\/\d{4}),\s*(\d{1,2}:\d{2}(?::\d{2})?)\]\s*(.+?):\s*(.*)$'

# %%
tuples_list = re.findall(pattern, data, re.MULTILINE)   #pachi pandas dataframe ma convert garna break down to list of tuples

# %%
tuples_list
# Out:
# [('15/11/2024',
#   '11:54:43',
#   'NCE 2080 BCT',
#   '\u200eMessages and calls are end-to-end encrypted. Only people in this chat can read, listen to, or share them.'),
#  ('15/11/2024',
#   '11:54:43',
#   '~\u202fEr.SP',
#   '\u200e~\u202fEr.SP created this group'),
#  ('15/11/2024', '11:54:43', 'NCE 2080 BCT', '\u200eYou were added'),
#  ('25/03/2025',
#   '21:18:32',
#   '~\u202fEr.SP',
#   '\u200eWaiting for this message. This may take a while.'),
#  ('25/03/2025',
#   '21:18:33',
#   '~\u202fEr.SP',
#   '\u200eWaiting for this message. This may take a while.'),
#  ('25/03/2025',
#   '21:18:33',
#   '~\u202fEr.SP',
#   '\u200eWaiting for this message. This may take a while.'),
#  ('25/03/2025',
#   '21:32:29',
#   '~\u202fEr.SP',
#   '\u200eWaiting for this message. This may take a while.'),
#  ('25/03/2025',
#   '21:32:32',
#   '~\u202fEr.SP',
#   '\u200eWaiting for this message. This may take a while.'),
#  ('26/03/2025',
#   '08:15:21',
#   'Suroj Burlakoti',
#   '\u200eWaiting for this message. This may take a while.'),
#  ('29/03/2025',
#   '10:02:26',
#   '~\u202fEr.SP',
#   '\u200eWaiting for this message. This may take a while.'),
#  ('05/04/2025',
#   '20:07:05',
#   '\u202a+977\xa0984‑9213538\u202c',
#   '\u200e\u202a+977\xa0984‑9213538\u202c left'),
#  ('15/04/2025',
#   '22:55:20',
#   '\u202a+9779766479265\u202c',
#   '\u200e\u200e\u202a+9779766479265\u202c changed their phone number to a new number. \u200eTap to message new number.'),
#  ('06/05/2025',
#   '08:58:46',
#   'Suroj Burlakoti',
#   'Dear Student, The Instrumentation class for tomorrow is shifted to 12:30 PM. So please reach college at 8:40AM for tomorrow.'),
#  ('06/05/2025',
#   '21:57:38',
#   '~\u202fSahil Subedi',
#   '\u200e~\u202fEr.SP added ~\u202fSahil Subedi'),
#  ('12/05/2025',
#   '13:14:41',
#   'Ranjit KC',
#   '\u200eSuroj Burlakoti added Ranjit KC'),
#  ('07/05/2025', '14:06:26', 'Suroj Burlakoti', 'Dear students, '),
#  ('07/05/2025', '17:29:45', 'Suroj Burlakoti', 'Class routine for tomorrow'),
#  ('08/05/2025',
#   '16:25:58',
#   'Asim Poudel',
#   'Sir bholi Pani instrumentation deuso hune ho?'),
#  ('08/05/2025',
#   '17:09:30',
#   'Suroj Burlakoti',
#   'Dear students, there will be Operating system class on tomorrow morning starting from 7:05 AM. Please reach college at 7:00 AM sharp.'),
#  ('08/05/2025',
#   '17:10:14',
#   'Suroj Burlakoti',
#   'OS and Instrumentation swapped.'),
#  ('08/05/2025', '17:10:27', 'Asim Poudel', 'Alright'),
#  ('11/05/2025',
#   '17:34:16',
#   'Suroj Burlakoti',
#   'Dear Student, please reach college at 7:00 AM sharp for Monday'),
#  ('17/05/2025', '15:50:05', 'Asim Poudel', 'Sir vayena esto ta'),
#  ('17/05/2025', '15:50:15', 'Asim Poudel', 'Friday ko 4 15 sammai hune?'),
#  ('21/05/2025',
#   '20:41:47',
#   'Suroj Burlakoti',
#   'Dear students, there will be no class of Instrumentation for tomorrow morning due to faculty unavailability. Please reach college at 8:45 AM. Sorry for your inconvenience.'),
#  ('23/05/2025',
#   '13:22:54',
#   'Sarwagya Acharya',
#   '\u200eYou deleted this message.'),
#  ('30/05/2025',
#   '10:16:32',
#   '~\u202fSahil Subedi',
#   "Syllabus of EM for third weekly test: Derivation of electric field intensity using Gauss's law. (Due to all types of charges)"),
#  ('02/06/2025',
#   '06:24:56',
#   '~\u202fEr.SP',
#   'Due to an unavoidable  situation, there will be no regular classes today (Monday, 2 June, 2025).'),
#  ('02/06/2025', '09:02:03', '~\u202fSahil Subedi', 'Dear Students,'),
#  ('03/06/2025',
#   '21:48:22',
#   'Suroj Burlakoti',
#   'Dear Students, there will be regular classes from tomorrow. Please reach college at 7:00AM.'),
#  ('13/06/2025',
#   '16:39:36',
#   'Asim Poudel',
#   'Sir 3 gate wala lai last ma shift garda hunxa ?'),
#  ('16/06/2025',
#   '09:11:58',
#   '~\u202fSahil Subedi',
#   'EM Practice Questions for Assessment 1'),
#  ('16/06/2025',
#   '10:01:06',
#   'Suroj Burlakoti',
#   'Dear students, the Assessment exam of DSA is shifted to Wednesday (2082/03/04) at 12:30 PM as per CR request. '),
#  ('17/06/2025', '12:54:52', 'Suroj Burlakoti', 'revised'),
#  ('18/06/2025', '09:15:34', '~\u202fSahil Subedi', 'Dear Students,'),
#  ('23/06/2025',
#   '18:21:55',
#   '~\u202fSahil Subedi',
#   '\u200eThis message was deleted.'),
#  ('23/06/2025',
#   '18:22:22',
#   '~\u202fSahil Subedi',
#   'Solution of Q3 and Q14 from Practice Set'),
#  ('23/06/2025',
#   '18:23:55',
#   '~\u202fSahil Subedi',
#   '\u200eThis message was deleted.'),
#  ('26/06/2025', '09:03:59', '~\u202fSahil Subedi', 'Dear Students,'),
#  ('30/06/2025', '15:51:43', 'Ranjit KC', '%Amplitude modulation   '),
#  ('30/06/2025', '15:51:44', 'Ranjit KC', '%Frequency modulation'),
#  ('04/07/2025',
#   '21:08:10',
#   '~\u202fSahil Subedi',
#   "\u200e~\u202fSahil Subedi changed this group's icon"),
#  ('19/07/2025',
#   '16:10:47',
#   'Suroj Burlakoti',
#   'Dear students, there will be electromagnetics class for Monday morning starting from 7:05AM in place of weekly test.'),
#  ('22/07/2025',
#   '18:31:27',
#   '~\u202fSahil Subedi',
#   '\u200eThis message was deleted.'),
#  ('22/07/2025',
#   '18:32:40',
#   '~\u202fSahil Subedi',
#   '*Reminder for Tomorrow:* Please ensure you are well-prepared with the following formulas and concepts.'),
#  ('27/07/2025', '19:20:40', 'Suroj Burlakoti', 'MONDAY 7:05 DSA class'),
#  ('30/07/2025', '17:48:59', 'Suroj Burlakoti', 'class schedule for tomorrow'),
#  ('30/07/2025',
#   '20:34:23',
#   '~\u202fSahil Subedi',
#   'This is to inform all students that a test of Electromagnetics will be conducted on Friday, 2082/04/16.'),
#  ('31/07/2025', '19:21:45', 'Suroj Burlakoti', 'class schedule for tomorrow'),
#  ('05/08/2025',
#   '17:29:57',
#   '~\u202fSahil Subedi',
#   '\u200eThis message was deleted.'),
#  ('13/08/2025',
#   '20:42:11',
#   '~\u202fSahil Subedi',
#   '*Notice:* Students who did not pass the final assessment are required to appear for a re-exam.'),
#  ('19/08/2025',
#   '17:26:25',
#   '~\u202fSahil Subedi',
#   'Dear Students, the re-exam scheduled on 2082/05/04 (Wednesday) has been *rescheduled* to *8:30 AM* instead of 11:00 AM.'),
#  ('20/08/2025', '08:18:02', '~\u202fSahil Subedi', 'Re- Exam: Room no. 101'),
#  ('21/08/2025',
#   '13:42:50',
#   '~\u202fSahil Subedi',
#   'Yo copy kasko ho, liyera jane'),
#  ('22/08/2025',
#   '10:01:03',
#   '~\u202fSahil Subedi',
#   'You can collect assessment copy of EM from my cabin.'),
#  ('22/08/2025',
#   '10:03:29',
#   '~\u202fSahil Subedi',
#   "Don't miss dot product and vector sign in your answer. You may get zero marks in final exam. Practice past questions, tutorial, and assessment question of other colg."),
#  ('09/09/2025', '09:18:19', 'Suroj Burlakoti', '*Dear Students,* '),
#  ('11/09/2025', '11:32:08', 'Suroj Burlakoti', 'Dear Students,')]

# %%
df = pd.DataFrame(tuples_list, columns=['Date', 'Time', 'Name', 'Message'])
df.head()
# Out:
#          Date      Time          Name  \
# 0  15/11/2024  11:54:43  NCE 2080 BCT
# 1  15/11/2024  11:54:43       ~ Er.SP
# 2  15/11/2024  11:54:43  NCE 2080 BCT
# 3  25/03/2025  21:18:32       ~ Er.SP
# 4  25/03/2025  21:18:33       ~ Er.SP
#
#                                              Message
# 0  ‎Messages and calls are end-to-end encrypted. ...
# 1                        ‎~ Er.SP created this group
# 2                                    ‎You were added
# 3  ‎Waiting for this message. This may take a while.
# 4  ‎Waiting for this message. This may take a while.

# %%
df['Date']  = pd.to_datetime(df['Date'], format='%d/%m/%Y')
df['Time']  = pd.to_datetime(df['Time'], format='%H:%M:%S').dt.time

# %%
df
# Out:
#          Date      Time                Name  \
# 0  2024-11-15  11:54:43        NCE 2080 BCT
# 1  2024-11-15  11:54:43             ~ Er.SP
# 2  2024-11-15  11:54:43        NCE 2080 BCT
# 3  2025-03-25  21:18:32             ~ Er.SP
# 4  2025-03-25  21:18:33             ~ Er.SP
# 5  2025-03-25  21:18:33             ~ Er.SP
# 6  2025-03-25  21:32:29             ~ Er.SP
# 7  2025-03-25  21:32:32             ~ Er.SP
# 8  2025-03-26  08:15:21     Suroj Burlakoti
# 9  2025-03-29  10:02:26             ~ Er.SP
# 10 2025-04-05  20:07:05  ‪+977 984‑9213538‬
# 11 2025-04-15  22:55:20    ‪+9779766479265‬
# 12 2025-05-06  08:58:46     Suroj Burlakoti
# 13 2025-05-06  21:57:38      ~ Sahil Subedi
# 14 2025-05-12  13:14:41           Ranjit KC
# 15 2025-05-07  14:06:26     Suroj Burlakoti
# 16 2025-05-07  17:29:45     Suroj Burlakoti
# 17 2025-05-08  16:25:58         Asim Poudel
# 18 2025-05-08  17:09:30     Suroj Burlakoti
# 19 2025-05-08  17:10:14     Suroj Burlakoti
# 20 2025-05-08  17:10:27         Asim Poudel
# 21 2025-05-11  17:34:16     Suroj Burlakoti
# 22 2025-05-17  15:50:05         Asim Poudel
# 23 2025-05-17  15:50:15         Asim Poudel
# 24 2025-05-21  20:41:47     Suroj Burlakoti
# 25 2025-05-23  13:22:54    Sarwagya Acharya
# 26 2025-05-30  10:16:32      ~ Sahil Subedi
# 27 2025-06-02  06:24:56             ~ Er.SP
# 28 2025-06-02  09:02:03      ~ Sahil Subedi
# 29 2025-06-03  21:48:22     Suroj Burlakoti
# 30 2025-06-13  16:39:36         Asim Poudel
# 31 2025-06-16  09:11:58      ~ Sahil Subedi
# 32 2025-06-16  10:01:06     Suroj Burlakoti
# 33 2025-06-17  12:54:52     Suroj Burlakoti
# 34 2025-06-18  09:15:34      ~ Sahil Subedi
# 35 2025-06-23  18:21:55      ~ Sahil Subedi
# 36 2025-06-23  18:22:22      ~ Sahil Subedi
# 37 2025-06-23  18:23:55      ~ Sahil Subedi
# 38 2025-06-26  09:03:59      ~ Sahil Subedi
# 39 2025-06-30  15:51:43           Ranjit KC
# 40 2025-06-30  15:51:44           Ranjit KC
# 41 2025-07-04  21:08:10      ~ Sahil Subedi
# 42 2025-07-19  16:10:47     Suroj Burlakoti
# 43 2025-07-22  18:31:27      ~ Sahil Subedi
# 44 2025-07-22  18:32:40      ~ Sahil Subedi
# 45 2025-07-27  19:20:40     Suroj Burlakoti
# 46 2025-07-30  17:48:59     Suroj Burlakoti
# 47 2025-07-30  20:34:23      ~ Sahil Subedi
# 48 2025-07-31  19:21:45     Suroj Burlakoti
# 49 2025-08-05  17:29:57      ~ Sahil Subedi
# 50 2025-08-13  20:42:11      ~ Sahil Subedi
# 51 2025-08-19  17:26:25      ~ Sahil Subedi
# 52 2025-08-20  08:18:02      ~ Sahil Subedi
# 53 2025-08-21  13:42:50      ~ Sahil Subedi
# 54 2025-08-22  10:01:03      ~ Sahil Subedi
# 55 2025-08-22  10:03:29      ~ Sahil Subedi
# 56 2025-09-09  09:18:19     Suroj Burlakoti
# 57 2025-09-11  11:32:08     Suroj Burlakoti
#
#                                               Message
# 0   ‎Messages and calls are end-to-end encrypted. ...
# 1                         ‎~ Er.SP created this group
# 2                                     ‎You were added
# 3   ‎Waiting for this message. This may take a while.
# 4   ‎Waiting for this message. This may take a while.
# 5   ‎Waiting for this message. This may take a while.
# 6   ‎Waiting for this message. This may take a while.
# 7   ‎Waiting for this message. This may take a while.
# 8   ‎Waiting for this message. This may take a while.
# 9   ‎Waiting for this message. This may take a while.
# 10                           ‎‪+977 984‑9213538‬ left
# 11  ‎‎‪+9779766479265‬ changed their phone number ...
# 12  Dear Student, The Instrumentation class for to...
# 13                      ‎~ Er.SP added ~ Sahil Subedi
# 14                   ‎Suroj Burlakoti added Ranjit KC
# 15                                    Dear students,
# 16                         Class routine for tomorrow
# 17      Sir bholi Pani instrumentation deuso hune ho?
# 18  Dear students, there will be Operating system ...
# 19                    OS and Instrumentation swapped.
# 20                                            Alright
# 21  Dear Student, please reach college at 7:00 AM ...
# 22                                 Sir vayena esto ta
# 23                        Friday ko 4 15 sammai hune?
# 24  Dear students, there will be no class of Instr...
# 25                         ‎You deleted this message.
# 26  Syllabus of EM for third weekly test: Derivati...
# 27  Due to an unavoidable  situation, there will b...
# 28                                     Dear Students,
# 29  Dear Students, there will be regular classes f...
# 30    Sir 3 gate wala lai last ma shift garda hunxa ?
# 31             EM Practice Questions for Assessment 1
# 32  Dear students, the Assessment exam of DSA is s...
# 33                                            revised
# 34                                     Dear Students,
# 35                         ‎This message was deleted.
# 36           Solution of Q3 and Q14 from Practice Set
# 37                         ‎This message was deleted.
# 38                                     Dear Students,
# 39                           %Amplitude modulation
# 40                              %Frequency modulation
# 41          ‎~ Sahil Subedi changed this group's icon
# 42  Dear students, there will be electromagnetics ...
# 43                         ‎This message was deleted.
# 44  *Reminder for Tomorrow:* Please ensure you are...
# 45                              MONDAY 7:05 DSA class
# 46                        class schedule for tomorrow
# 47  This is to inform all students that a test of ...
# 48                        class schedule for tomorrow
# 49                         ‎This message was deleted.
# 50  *Notice:* Students who did not pass the final ...
# 51  Dear Students, the re-exam scheduled on 2082/0...
# 52                             Re- Exam: Room no. 101
# 53                      Yo copy kasko ho, liyera jane
# 54  You can collect assessment copy of EM from my ...
# 55  Don't miss dot product and vector sign in your...
# 56                                  *Dear Students,*
# 57                                     Dear Students,

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month_name()
df['Day'] = df['Date'].dt.day_name()
df['Hour'] = pd.to_datetime(df['Time'], format='%H:%M:%S').dt.hour
df['Minute'] = pd.to_datetime(df['Time'], format='%H:%M:%S').dt.minute

# %%
df
# Out:
#          Date      Time                Name  \
# 0  2024-11-15  11:54:43        NCE 2080 BCT
# 1  2024-11-15  11:54:43             ~ Er.SP
# 2  2024-11-15  11:54:43        NCE 2080 BCT
# 3  2025-03-25  21:18:32             ~ Er.SP
# 4  2025-03-25  21:18:33             ~ Er.SP
# 5  2025-03-25  21:18:33             ~ Er.SP
# 6  2025-03-25  21:32:29             ~ Er.SP
# 7  2025-03-25  21:32:32             ~ Er.SP
# 8  2025-03-26  08:15:21     Suroj Burlakoti
# 9  2025-03-29  10:02:26             ~ Er.SP
# 10 2025-04-05  20:07:05  ‪+977 984‑9213538‬
# 11 2025-04-15  22:55:20    ‪+9779766479265‬
# 12 2025-05-06  08:58:46     Suroj Burlakoti
# 13 2025-05-06  21:57:38      ~ Sahil Subedi
# 14 2025-05-12  13:14:41           Ranjit KC
# 15 2025-05-07  14:06:26     Suroj Burlakoti
# 16 2025-05-07  17:29:45     Suroj Burlakoti
# 17 2025-05-08  16:25:58         Asim Poudel
# 18 2025-05-08  17:09:30     Suroj Burlakoti
# 19 2025-05-08  17:10:14     Suroj Burlakoti
# 20 2025-05-08  17:10:27         Asim Poudel
# 21 2025-05-11  17:34:16     Suroj Burlakoti
# 22 2025-05-17  15:50:05         Asim Poudel
# 23 2025-05-17  15:50:15         Asim Poudel
# 24 2025-05-21  20:41:47     Suroj Burlakoti
# 25 2025-05-23  13:22:54    Sarwagya Acharya
# 26 2025-05-30  10:16:32      ~ Sahil Subedi
# 27 2025-06-02  06:24:56             ~ Er.SP
# 28 2025-06-02  09:02:03      ~ Sahil Subedi
# 29 2025-06-03  21:48:22     Suroj Burlakoti
# 30 2025-06-13  16:39:36         Asim Poudel
# 31 2025-06-16  09:11:58      ~ Sahil Subedi
# 32 2025-06-16  10:01:06     Suroj Burlakoti
# 33 2025-06-17  12:54:52     Suroj Burlakoti
# 34 2025-06-18  09:15:34      ~ Sahil Subedi
# 35 2025-06-23  18:21:55      ~ Sahil Subedi
# 36 2025-06-23  18:22:22      ~ Sahil Subedi
# 37 2025-06-23  18:23:55      ~ Sahil Subedi
# 38 2025-06-26  09:03:59      ~ Sahil Subedi
# 39 2025-06-30  15:51:43           Ranjit KC
# 40 2025-06-30  15:51:44           Ranjit KC
# 41 2025-07-04  21:08:10      ~ Sahil Subedi
# 42 2025-07-19  16:10:47     Suroj Burlakoti
# 43 2025-07-22  18:31:27      ~ Sahil Subedi
# 44 2025-07-22  18:32:40      ~ Sahil Subedi
# 45 2025-07-27  19:20:40     Suroj Burlakoti
# 46 2025-07-30  17:48:59     Suroj Burlakoti
# 47 2025-07-30  20:34:23      ~ Sahil Subedi
# 48 2025-07-31  19:21:45     Suroj Burlakoti
# 49 2025-08-05  17:29:57      ~ Sahil Subedi
# 50 2025-08-13  20:42:11      ~ Sahil Subedi
# 51 2025-08-19  17:26:25      ~ Sahil Subedi
# 52 2025-08-20  08:18:02      ~ Sahil Subedi
# 53 2025-08-21  13:42:50      ~ Sahil Subedi
# 54 2025-08-22  10:01:03      ~ Sahil Subedi
# 55 2025-08-22  10:03:29      ~ Sahil Subedi
# 56 2025-09-09  09:18:19     Suroj Burlakoti
# 57 2025-09-11  11:32:08     Suroj Burlakoti
#
#                                               Message  Year      Month  \
# 0   ‎Messages and calls are end-to-end encrypted. ...  2024   November
# 1                         ‎~ Er.SP created this group  2024   November
# 2                                     ‎You were added  2024   November
# 3   ‎Waiting for this message. This may take a while.  2025      March
# 4   ‎Waiting for this message. This may take a while.  2025      March
# 5   ‎Waiting for this message. This may take a while.  2025      March
# 6   ‎Waiting for this message. This may take a while.  2025      March
# 7   ‎Waiting for this message. This may take a while.  2025      March
# 8   ‎Waiting for this message. This may take a while.  2025      March
# 9   ‎Waiting for this message. This may take a while.  2025      March
# 10                           ‎‪+977 984‑9213538‬ left  2025      April
# 11  ‎‎‪+9779766479265‬ changed their phone number ...  2025      April
# 12  Dear Student, The Instrumentation class for to...  2025        May
# 13                      ‎~ Er.SP added ~ Sahil Subedi  2025        May
# 14                   ‎Suroj Burlakoti added Ranjit KC  2025        May
# 15                                    Dear students,   2025        May
# 16                         Class routine for tomorrow  2025        May
# 17      Sir bholi Pani instrumentation deuso hune ho?  2025        May
# 18  Dear students, there will be Operating system ...  2025        May
# 19                    OS and Instrumentation swapped.  2025        May
# 20                                            Alright  2025        May
# 21  Dear Student, please reach college at 7:00 AM ...  2025        May
# 22                                 Sir vayena esto ta  2025        May
# 23                        Friday ko 4 15 sammai hune?  2025        May
# 24  Dear students, there will be no class of Instr...  2025        May
# 25                         ‎You deleted this message.  2025        May
# 26  Syllabus of EM for third weekly test: Derivati...  2025        May
# 27  Due to an unavoidable  situation, there will b...  2025       June
# 28                                     Dear Students,  2025       June
# 29  Dear Students, there will be regular classes f...  2025       June
# 30    Sir 3 gate wala lai last ma shift garda hunxa ?  2025       June
# 31             EM Practice Questions for Assessment 1  2025       June
# 32  Dear students, the Assessment exam of DSA is s...  2025       June
# 33                                            revised  2025       June
# 34                                     Dear Students,  2025       June
# 35                         ‎This message was deleted.  2025       June
# 36           Solution of Q3 and Q14 from Practice Set  2025       June
# 37                         ‎This message was deleted.  2025       June
# 38                                     Dear Students,  2025       June
# 39                           %Amplitude modulation     2025       June
# 40                              %Frequency modulation  2025       June
# 41          ‎~ Sahil Subedi changed this group's icon  2025       July
# 42  Dear students, there will be electromagnetics ...  2025       July
# 43                         ‎This message was deleted.  2025       July
# 44  *Reminder for Tomorrow:* Please ensure you are...  2025       July
# 45                              MONDAY 7:05 DSA class  2025       July
# 46                        class schedule for tomorrow  2025       July
# 47  This is to inform all students that a test of ...  2025       July
# 48                        class schedule for tomorrow  2025       July
# 49                         ‎This message was deleted.  2025     August
# 50  *Notice:* Students who did not pass the final ...  2025     August
# 51  Dear Students, the re-exam scheduled on 2082/0...  2025     August
# 52                             Re- Exam: Room no. 101  2025     August
# 53                      Yo copy kasko ho, liyera jane  2025     August
# 54  You can collect assessment copy of EM from my ...  2025     August
# 55  Don't miss dot product and vector sign in your...  2025     August
# 56                                  *Dear Students,*   2025  September
# 57                                     Dear Students,  2025  September
#
#           Day  Hour  Minute
# 0      Friday    11      54
# 1      Friday    11      54
# 2      Friday    11      54
# 3     Tuesday    21      18
# 4     Tuesday    21      18
# 5     Tuesday    21      18
# 6     Tuesday    21      32
# 7     Tuesday    21      32
# 8   Wednesday     8      15
# 9    Saturday    10       2
# 10   Saturday    20       7
# 11    Tuesday    22      55
# 12    Tuesday     8      58
# 13    Tuesday    21      57
# 14     Monday    13      14
# 15  Wednesday    14       6
# 16  Wednesday    17      29
# 17   Thursday    16      25
# 18   Thursday    17       9
# 19   Thursday    17      10
# 20   Thursday    17      10
# 21     Sunday    17      34
# 22   Saturday    15      50
# 23   Saturday    15      50
# 24  Wednesday    20      41
# 25     Friday    13      22
# 26     Friday    10      16
# 27     Monday     6      24
# 28     Monday     9       2
# 29    Tuesday    21      48
# 30     Friday    16      39
# 31     Monday     9      11
# 32     Monday    10       1
# 33    Tuesday    12      54
# 34  Wednesday     9      15
# 35     Monday    18      21
# 36     Monday    18      22
# 37     Monday    18      23
# 38   Thursday     9       3
# 39     Monday    15      51
# 40     Monday    15      51
# 41     Friday    21       8
# 42   Saturday    16      10
# 43    Tuesday    18      31
# 44    Tuesday    18      32
# 45     Sunday    19      20
# 46  Wednesday    17      48
# 47  Wednesday    20      34
# 48   Thursday    19      21
# 49    Tuesday    17      29
# 50  Wednesday    20      42
# 51    Tuesday    17      26
# 52  Wednesday     8      18
# 53   Thursday    13      42
# 54     Friday    10       1
# 55     Friday    10       3
# 56    Tuesday     9      18
# 57   Thursday    11      32

# %%
def normalize(text):
    if isinstance(text, str):
        # Remove all common invisible/Unicode control characters from WhatsApp exports
        text = re.sub(r'[\u200b-\u200f\u202a-\u202e\u202f\u00a0\u00ad\uFEFF\u2011]', '', text)
        return text.strip()
    return text

# Normalize both columns
df['Name'] = df['Name'].apply(normalize)
df['Message'] = df['Message'].apply(normalize)

unique_names = df['Name'].unique().tolist()

# %%
unique_names
# Out:
# ['NCE 2080 BCT',
#  '~Er.SP',
#  'Suroj Burlakoti',
#  '+9779849213538',
#  '+9779766479265',
#  '~Sahil Subedi',
#  'Ranjit KC',
#  'Asim Poudel',
#  'Sarwagya Acharya']

# %%
notification_patterns = [
    r'^.* left$',          # X left
    r'^.* added .+$',      # X added Y
    r'^.* removed .+$',    # X removed Y
    r'^.* created this group$',
    r'^Waiting for this message\. This may take a while\.$',
    r'^.* changed their phone number.*$',
    r'^.* deleted this message.*$',
    r'^image omitted$',
    r'^document omitted$',
    r'^Tap to message new number$',
    r'^This message was deleted\.$',
    r'^You were added$',
    r'^You deleted this message\.$',
    r'^changed the subject from.*$',
    r"^changed this group's settings.*$",
    r'^changed the group description.*$',
    r"^changed this group's icon.*$",
    r'^Messages and calls are end-to-end encrypted.*$'
]

# Apply regex filter
notification_mask = ~df['Message'].str.match('|'.join(notification_patterns), case=False)
df_cleaned = df[notification_mask].reset_index(drop=True)

# %%
df_cleaned
# Out:
#          Date      Time             Name  \
# 0  2025-05-06  08:58:46  Suroj Burlakoti
# 1  2025-05-07  14:06:26  Suroj Burlakoti
# 2  2025-05-07  17:29:45  Suroj Burlakoti
# 3  2025-05-08  16:25:58      Asim Poudel
# 4  2025-05-08  17:09:30  Suroj Burlakoti
# 5  2025-05-08  17:10:14  Suroj Burlakoti
# 6  2025-05-08  17:10:27      Asim Poudel
# 7  2025-05-11  17:34:16  Suroj Burlakoti
# 8  2025-05-17  15:50:05      Asim Poudel
# 9  2025-05-17  15:50:15      Asim Poudel
# 10 2025-05-21  20:41:47  Suroj Burlakoti
# 11 2025-05-30  10:16:32    ~Sahil Subedi
# 12 2025-06-02  06:24:56           ~Er.SP
# 13 2025-06-02  09:02:03    ~Sahil Subedi
# 14 2025-06-03  21:48:22  Suroj Burlakoti
# 15 2025-06-13  16:39:36      Asim Poudel
# 16 2025-06-16  09:11:58    ~Sahil Subedi
# 17 2025-06-16  10:01:06  Suroj Burlakoti
# 18 2025-06-17  12:54:52  Suroj Burlakoti
# 19 2025-06-18  09:15:34    ~Sahil Subedi
# 20 2025-06-23  18:22:22    ~Sahil Subedi
# 21 2025-06-26  09:03:59    ~Sahil Subedi
# 22 2025-06-30  15:51:43        Ranjit KC
# 23 2025-06-30  15:51:44        Ranjit KC
# 24 2025-07-04  21:08:10    ~Sahil Subedi
# 25 2025-07-19  16:10:47  Suroj Burlakoti
# 26 2025-07-22  18:32:40    ~Sahil Subedi
# 27 2025-07-27  19:20:40  Suroj Burlakoti
# 28 2025-07-30  17:48:59  Suroj Burlakoti
# 29 2025-07-30  20:34:23    ~Sahil Subedi
# 30 2025-07-31  19:21:45  Suroj Burlakoti
# 31 2025-08-13  20:42:11    ~Sahil Subedi
# 32 2025-08-19  17:26:25    ~Sahil Subedi
# 33 2025-08-20  08:18:02    ~Sahil Subedi
# 34 2025-08-21  13:42:50    ~Sahil Subedi
# 35 2025-08-22  10:01:03    ~Sahil Subedi
# 36 2025-08-22  10:03:29    ~Sahil Subedi
# 37 2025-09-09  09:18:19  Suroj Burlakoti
# 38 2025-09-11  11:32:08  Suroj Burlakoti
#
#                                               Message  Year      Month  \
# 0   Dear Student, The Instrumentation class for to...  2025        May
# 1                                      Dear students,  2025        May
# 2                          Class routine for tomorrow  2025        May
# 3       Sir bholi Pani instrumentation deuso hune ho?  2025        May
# 4   Dear students, there will be Operating system ...  2025        May
# 5                     OS and Instrumentation swapped.  2025        May
# 6                                             Alright  2025        May
# 7   Dear Student, please reach college at 7:00 AM ...  2025        May
# 8                                  Sir vayena esto ta  2025        May
# 9                         Friday ko 4 15 sammai hune?  2025        May
# 10  Dear students, there will be no class of Instr...  2025        May
# 11  Syllabus of EM for third weekly test: Derivati...  2025        May
# 12  Due to an unavoidable  situation, there will b...  2025       June
# 13                                     Dear Students,  2025       June
# 14  Dear Students, there will be regular classes f...  2025       June
# 15    Sir 3 gate wala lai last ma shift garda hunxa ?  2025       June
# 16             EM Practice Questions for Assessment 1  2025       June
# 17  Dear students, the Assessment exam of DSA is s...  2025       June
# 18                                            revised  2025       June
# 19                                     Dear Students,  2025       June
# 20           Solution of Q3 and Q14 from Practice Set  2025       June
# 21                                     Dear Students,  2025       June
# 22                              %Amplitude modulation  2025       June
# 23                              %Frequency modulation  2025       June
# 24            ~Sahil Subedi changed this group's icon  2025       July
# 25  Dear students, there will be electromagnetics ...  2025       July
# 26  *Reminder for Tomorrow:* Please ensure you are...  2025       July
# 27                              MONDAY 7:05 DSA class  2025       July
# 28                        class schedule for tomorrow  2025       July
# 29  This is to inform all students that a test of ...  2025       July
# 30                        class schedule for tomorrow  2025       July
# 31  *Notice:* Students who did not pass the final ...  2025     August
# 32  Dear Students, the re-exam scheduled on 2082/0...  2025     August
# 33                             Re- Exam: Room no. 101  2025     August
# 34                      Yo copy kasko ho, liyera jane  2025     August
# 35  You can collect assessment copy of EM from my ...  2025     August
# 36  Don't miss dot product and vector sign in your...  2025     August
# 37                                   *Dear Students,*  2025  September
# 38                                     Dear Students,  2025  September
#
#           Day  Hour  Minute
# 0     Tuesday     8      58
# 1   Wednesday    14       6
# 2   Wednesday    17      29
# 3    Thursday    16      25
# 4    Thursday    17       9
# 5    Thursday    17      10
# 6    Thursday    17      10
# 7      Sunday    17      34
# 8    Saturday    15      50
# 9    Saturday    15      50
# 10  Wednesday    20      41
# 11     Friday    10      16
# 12     Monday     6      24
# 13     Monday     9       2
# 14    Tuesday    21      48
# 15     Friday    16      39
# 16     Monday     9      11
# 17     Monday    10       1
# 18    Tuesday    12      54
# 19  Wednesday     9      15
# 20     Monday    18      22
# 21   Thursday     9       3
# 22     Monday    15      51
# 23     Monday    15      51
# 24     Friday    21       8
# 25   Saturday    16      10
# 26    Tuesday    18      32
# 27     Sunday    19      20
# 28  Wednesday    17      48
# 29  Wednesday    20      34
# 30   Thursday    19      21
# 31  Wednesday    20      42
# 32    Tuesday    17      26
# 33  Wednesday     8      18
# 34   Thursday    13      42
# 35     Friday    10       1
# 36     Friday    10       3
# 37    Tuesday     9      18
# 38   Thursday    11      32
